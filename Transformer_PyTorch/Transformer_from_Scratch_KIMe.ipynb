# %%
# %matplotlib inline

# %%
# !pip install -q torch==2.3 torchtext torchdata torchmetrics spacy datasets
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.2/779.2 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 86.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 73.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 41.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 6.7 MB/s eta 0:00:00
# ...

# %%
# 설치 확인
# !pip list | grep -E "torch|cuda|spacy|portalocker|folium"
# Out:
# cuda-python                        12.6.0
# cupy-cuda12x                       13.3.0
# folium                             0.19.4
# jax-cuda12-pjrt                    0.4.33
# jax-cuda12-plugin                  0.4.33
# numba-cuda                         0.0.17.1
# nvidia-cuda-cupti-cu12             12.1.105
# nvidia-cuda-nvcc-cu12              12.5.82
# nvidia-cuda-nvrtc-cu12             12.1.105
# nvidia-cuda-runtime-cu12           12.1.105
# spacy                              3.7.5
# spacy-legacy                       3.0.12
# spacy-loggers                      1.0.5
# torch                              2.3.0
# torchaudio                         2.5.1+cu124
# torchdata                          0.10.1
# torchmetrics                       1.6.1
# torchsummary                       1.5.1
# torchtext                          0.18.0
# torchvision                        0.20.1+cu124

# %%
# %cd /content
# !rm -rf tfr
# !git clone https://github.com/ES7/Transformer-from-Scratch.git tfr
# Out:
# /content
# Cloning into 'tfr'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 28 (delta 7), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (28/28), 16.17 KiB | 318.00 KiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# # Git clone the specific folder @ Google Colab
# %cd /content
# !rm -rf test

# !git init test
# %cd test
# !pwd
# !git remote add -f origin https://github.com/knowledge-intelligence/KIMe-Tutorials.git
# !git config core.sparseCheckout true
# !echo ROS2_Nav2/ >> .git/info/sparse-checkout
# !git pull origin main

# %%
# !pwd
# %cd /content/tfr
# !pwd
# Out:
# /content
# /content/tfr
# /content/tfr

# %%
# from model import build_transformer
# from dataset import TranslationDataset, causal_mask
# from config import get_config, get_weights_file_path, latest_weights_file_path
from train import train_model
import warnings

warnings.filterwarnings("ignore")

def get_config():
    return {
        "batch_size": 16,
        "num_epochs": 2,
        "lr": 10**-4,
        "seq": 350,
        "d_model": 512,
        "datasource": 'opus_books',
        "lang_src": "en",
        "lang_tgt": "it",
        "model_folder": "weights",
        "model_basename": "tmodel_",
        "preload": "latest",
        "tokenizer_file": "tokenizer_{0}.json",
        "experiment_name": "runs/tmodel"
    }

config = get_config()
train_model(config)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchtext/datasets/__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# /usr/local/lib/python3.11/dist-packages/torchtext/data/__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# Using device: cuda
# Device name: Tesla T4
# Device memory: 14.74127197265625 GB
# ...
